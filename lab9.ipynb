# %% [markdown]
# # tower of hanoi

# %%
# !sudo apt-get install swi-prolog
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swi-prolog is already the newest version (8.4.2+dfsg-2ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %%
# %%writefile tower.pl
#
# move(1, Source, Target, _) :-
#     format('Move disk from ~w to ~w~n', [Source, Target]).
#
# move(N, Source, Target, Aux) :-
#     N > 1,
#     M is N - 1,
#     move(M, Source, Aux, Target),
#     move(1, Source, Target, _),
#     move(M, Aux, Target, Source).
#
# hanoi(N) :-
#     move(N, 'Left Tower', 'Right Tower', 'Center Tower').
#
# :- initialization(hanoi(3)).
# Out:
# Overwriting tower.pl

# %%
# !swipl -q -s tower.pl
# Out:
# Move disk from Left Tower to Right Tower
# Move disk from Left Tower to Center Tower
# Move disk from Right Tower to Center Tower
# Move disk from Left Tower to Right Tower
# Move disk from Center Tower to Left Tower
# Move disk from Center Tower to Right Tower
# Move disk from Left Tower to Right Tower
# ?- halt.
